# %%
class Erp:
    def __init__(self):
        self.student_data={}
        self.faculty_data={}
        self.student_mark={}
    def new_student(self):
        name=input("enter your roll no")
        password=input("enter the password")
        self.student_data.update({name:password})
        self.student_mark.update({name:[]})
    def new_faculty(self):
        name=input("sir/madam \n , please enter your faculty id")
        password=input("please enter your password")
        self.faculty_data.update({name:password})
    def add_marks(self):
        name=input("enter your faculty_id")
        password=input("enter the password:")
        if(self.student_data[name]==password):
            for key,value in self.student_data.items():
                mark=int(input(f"enter the mark obtained by {key}:"))
                student_mark[key].append(mark)
        elif(self.student_data[name]==None):
            print(f"There is no such student details are there in our erp.....")
    def show_mark(self):
        name=input("enter your name(faculty/student):")
        password=input(f"enter the password for the {name}")
        if(name in student_data):
            if(student_data[name]==password):
                print(f"Your percentage is:{sum(student_mark[name])/len(student_mark[name])}")
            else:
                print("Wrong password try again later.....")
        elif(name in faculty_data):
            if(faculty_data[name]==password):
                for key,value in self.student_mark.items():
                    print(f"{key}:{sum(student_mark[key])/len(student_mark[key])}")
            else:
                print("wrong password please try again later.....")

# %%
# Out:
# {'24': '23'}
